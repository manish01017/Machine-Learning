# %% [markdown]
# 📚 NLTK pos_tag – Overview of the POS Tag Set (Penn Treebank)
#
# Tag	Description	Example
# CC	Coordinating conjunction	and, but, or
# CD	Cardinal number	one, 23
# DT	Determiner	the, a, this
# EX	Existential there	there
# FW	Foreign word	résumé
# IN	Preposition or subordinating conjunction	on, of, because
# JJ	Adjective	big, beautiful
# JJR	Adjective, comparative	bigger
# JJS	Adjective, superlative	biggest
# LS	List item marker	1., a)
# MD	Modal verb	can, will, should
# NN	Noun, singular or mass	dog, music
# NNS	Noun, plural	dogs, songs
# NNP	Proper noun, singular	London, Alice
# NNPS	Proper noun, plural	Britains, Atlases
# PDT	Predeterminer	all, both
# POS	Possessive ending	's
# PRP	Personal pronoun	I, you, he
# PRP$	Possessive pronoun	my, your, his
# RB	Adverb	quickly, very
# RBR	Adverb, comparative	faster
# RBS	Adverb, superlative	fastest
# RP	Particle	up, out
# SYM	Symbol	+, =, %
# TO	to as preposition/infinitive marker	to
# UH	Interjection	oh, wow
# VB	Verb, base form	run
# VBD	Verb, past tense	ran
# VBG	Verb, gerund/present participle	running
# VBN	Verb, past participle	run (as in has run)
# VBP	Verb, non‑3rd person singular present	run (I/you/we/they)
# VBZ	Verb, 3rd person singular present	runs
# WDT	Wh‑determiner	which
# WP	Wh‑pronoun	who, what
# WP$	Possessive wh‑pronoun	whose
# WRB	Wh‑adverb	where, why

# %%
speech = """Dear friends, I am very happy to be with you all on this special occasion. Today, we celebrate freedom, a value that is deeply cherished in our hearts. Freedom is not just a word; it is a way of life that empowers us to dream, to innovate, and to create a better future for ourselves and our nation.
As we gather here, let us remember the sacrifices made by our forefathers who fought tirelessly for our independence. Their courage and determination have paved the way for us to enjoy the liberties we have today. It is our duty to honor their legacy by upholding the principles of freedom, equality, and justice in our daily lives.
Freedom also comes with responsibilities. It is essential that we use our freedom wisely, respecting the rights of others and contributing positively to society. Let us embrace freedom with a sense of purpose, working together to build a nation that thrives on unity, diversity, and progress.
On this day, let us renew our commitment to the ideals of freedom and strive to make our country a beacon of hope and opportunity for all. Together, we can create a future where every individual has the freedom to pursue their dreams and aspirations.
Freedom is the oxygen of the soul, and as we breathe in this freedom, let us also breathe out love, compassion, and understanding towards one another.
children are the future of our nation, and it is our responsibility to ensure that they grow up in an environment where freedom is cherished and protected. Let us teach them the value of freedom and the importance of using it for the greater good.
In conclusion, let us celebrate freedom with gratitude and pride. May we always remember that freedom is a precious gift that we must cherish and protect for ourselves and future generations.
nation is our collective home, and freedom is the foundation upon which we build our dreams. Let us work together to create a future where freedom flourishes and every citizen can live with dignity and respect.
india is a land of diversity, and our freedom is a testament to the strength that comes from embracing our differences. Let us celebrate this diversity and work towards a harmonious society where everyone can enjoy their freedoms without fear or discrimination.
Thank you, and Jai Hind!
"""

# %%
import nltk

nltk.download('averaged_perceptron_tagger_eng')

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\manis\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\manis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
## POS tagging
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords

words=word_tokenize(speech)
words= [w for w in words if w not in set(stopwords.words('english'))]


words
# Out:
# ['Dear',
#  'friends',
#  ',',
#  'I',
#  'happy',
#  'special',
#  'occasion',
#  '.',
#  'Today',
#  ',',
#  'celebrate',
#  'freedom',
#  ',',
#  'value',
#  'deeply',
#  'cherished',
#  'hearts',
#  '.',
#  'Freedom',
#  'word',
#  ';',
#  'way',
#  'life',
#  'empowers',
#  'us',
#  'dream',
#  ',',
#  'innovate',
#  ',',
#  'create',
#  'better',
#  'future',
#  'nation',
#  '.',
#  'As',
#  'gather',
#  ',',
#  'let',
#  'us',
#  'remember',
#  'sacrifices',
#  'made',
#  'forefathers',
#  'fought',
#  'tirelessly',
#  'independence',
#  '.',
#  'Their',
#  'courage',
#  'determination',
#  'paved',
#  'way',
#  'us',
#  'enjoy',
#  'liberties',
#  'today',
#  '.',
#  'It',
#  'duty',
#  'honor',
#  'legacy',
#  'upholding',
#  'principles',
#  'freedom',
#  ',',
#  'equality',
#  ',',
#  'justice',
#  'daily',
#  'lives',
#  '.',
#  'Freedom',
#  'also',
#  'comes',
#  'responsibilities',
#  '.',
#  'It',
#  'essential',
#  'use',
#  'freedom',
#  'wisely',
#  ',',
#  'respecting',
#  'rights',
#  'others',
#  'contributing',
#  'positively',
#  'society',
#  '.',
#  'Let',
#  'us',
#  'embrace',
#  'freedom',
#  'sense',
#  'purpose',
#  ',',
#  'working',
#  'together',
#  'build',
#  'nation',
#  'thrives',
#  'unity',
#  ',',
#  'diversity',
#  ',',
#  'progress',
#  '.',
#  'On',
#  'day',
#  ',',
#  'let',
#  'us',
#  'renew',
#  'commitment',
#  'ideals',
#  'freedom',
#  'strive',
#  'make',
#  'country',
#  'beacon',
#  'hope',
#  'opportunity',
#  '.',
#  'Together',
#  ',',
#  'create',
#  'future',
#  'every',
#  'individual',
#  'freedom',
#  'pursue',
#  'dreams',
#  'aspirations',
#  '.',
#  'Freedom',
#  'oxygen',
#  'soul',
#  ',',
#  'breathe',
#  'freedom',
#  ',',
#  'let',
#  'us',
#  'also',
#  'breathe',
#  'love',
#  ',',
#  'compassion',
#  ',',
#  'understanding',
#  'towards',
#  'one',
#  'another',
#  '.',
#  'children',
#  'future',
#  'nation',
#  ',',
#  'responsibility',
#  'ensure',
#  'grow',
#  'environment',
#  'freedom',
#  'cherished',
#  'protected',
#  '.',
#  'Let',
#  'us',
#  'teach',
#  'value',
#  'freedom',
#  'importance',
#  'using',
#  'greater',
#  'good',
#  '.',
#  'In',
#  'conclusion',
#  ',',
#  'let',
#  'us',
#  'celebrate',
#  'freedom',
#  'gratitude',
#  'pride',
#  '.',
#  'May',
#  'always',
#  'remember',
#  'freedom',
#  'precious',
#  'gift',
#  'must',
#  'cherish',
#  'protect',
#  'future',
#  'generations',
#  '.',
#  'nation',
#  'collective',
#  'home',
#  ',',
#  'freedom',
#  'foundation',
#  'upon',
#  'build',
#  'dreams',
#  '.',
#  'Let',
#  'us',
#  'work',
#  'together',
#  'create',
#  'future',
#  'freedom',
#  'flourishes',
#  'every',
#  'citizen',
#  'live',
#  'dignity',
#  'respect',
#  '.',
#  'india',
#  'land',
#  'diversity',
#  ',',
#  'freedom',
#  'testament',
#  'strength',
#  'comes',
#  'embracing',
#  'differences',
#  '.',
#  'Let',
#  'us',
#  'celebrate',
#  'diversity',
#  'work',
#  'towards',
#  'harmonious',
#  'society',
#  'everyone',
#  'enjoy',
#  'freedoms',
#  'without',
#  'fear',
#  'discrimination',
#  '.',
#  'Thank',
#  ',',
#  'Jai',
#  'Hind',
#  '!']

# %%
#nltk.pos_tag can be applied on words and sentences

import nltk

pos_tagging=nltk.pos_tag(words)

pos_tagging
# Out:
# [('Dear', 'NNP'),
#  ('friends', 'NNS'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('happy', 'VBP'),
#  ('special', 'JJ'),
#  ('occasion', 'NN'),
#  ('.', '.'),
#  ('Today', 'NN'),
#  (',', ','),
#  ('celebrate', 'NN'),
#  ('freedom', 'NN'),
#  (',', ','),
#  ('value', 'NN'),
#  ('deeply', 'RB'),
#  ('cherished', 'VBD'),
#  ('hearts', 'NNS'),
#  ('.', '.'),
#  ('Freedom', 'NNP'),
#  ('word', 'NN'),
#  (';', ':'),
#  ('way', 'NN'),
#  ('life', 'NN'),
#  ('empowers', 'NNS'),
#  ('us', 'PRP'),
#  ('dream', 'VBP'),
#  (',', ','),
#  ('innovate', 'VBP'),
#  (',', ','),
#  ('create', 'VBP'),
#  ('better', 'JJR'),
#  ('future', 'JJ'),
#  ('nation', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('gather', 'NN'),
#  (',', ','),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('remember', 'VB'),
#  ('sacrifices', 'NNS'),
#  ('made', 'VBN'),
#  ('forefathers', 'NNS'),
#  ('fought', 'VBD'),
#  ('tirelessly', 'RB'),
#  ('independence', 'NN'),
#  ('.', '.'),
#  ('Their', 'PRP$'),
#  ('courage', 'NN'),
#  ('determination', 'NN'),
#  ('paved', 'VBD'),
#  ('way', 'NN'),
#  ('us', 'PRP'),
#  ('enjoy', 'VBP'),
#  ('liberties', 'NNS'),
#  ('today', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('duty', 'VBZ'),
#  ('honor', 'JJ'),
#  ('legacy', 'NN'),
#  ('upholding', 'JJ'),
#  ('principles', 'NNS'),
#  ('freedom', 'RB'),
#  (',', ','),
#  ('equality', 'NN'),
#  (',', ','),
#  ('justice', 'NN'),
#  ('daily', 'JJ'),
#  ('lives', 'VBZ'),
#  ('.', '.'),
#  ('Freedom', 'NNP'),
#  ('also', 'RB'),
#  ('comes', 'VBZ'),
#  ('responsibilities', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('essential', 'JJ'),
#  ('use', 'NN'),
#  ('freedom', 'NN'),
#  ('wisely', 'RB'),
#  (',', ','),
#  ('respecting', 'VBG'),
#  ('rights', 'NNS'),
#  ('others', 'NNS'),
#  ('contributing', 'VBG'),
#  ('positively', 'RB'),
#  ('society', 'NN'),
#  ('.', '.'),
#  ('Let', 'VB'),
#  ('us', 'PRP'),
#  ('embrace', 'VB'),
#  ('freedom', 'NN'),
#  ('sense', 'NN'),
#  ('purpose', 'NN'),
#  (',', ','),
#  ('working', 'VBG'),
#  ('together', 'RB'),
#  ('build', 'JJ'),
#  ('nation', 'NN'),
#  ('thrives', 'NNS'),
#  ('unity', 'NN'),
#  (',', ','),
#  ('diversity', 'NN'),
#  (',', ','),
#  ('progress', 'NN'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('day', 'NN'),
#  (',', ','),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('renew', 'VB'),
#  ('commitment', 'JJ'),
#  ('ideals', 'NNS'),
#  ('freedom', 'VBP'),
#  ('strive', 'JJ'),
#  ('make', 'VBP'),
#  ('country', 'NN'),
#  ('beacon', 'NN'),
#  ('hope', 'VBP'),
#  ('opportunity', 'NN'),
#  ('.', '.'),
#  ('Together', 'RB'),
#  (',', ','),
#  ('create', 'VB'),
#  ('future', 'JJ'),
#  ('every', 'DT'),
#  ('individual', 'NN'),
#  ('freedom', 'NN'),
#  ('pursue', 'NN'),
#  ('dreams', 'VBZ'),
#  ('aspirations', 'NNS'),
#  ('.', '.'),
#  ('Freedom', 'NNP'),
#  ('oxygen', 'NN'),
#  ('soul', 'NN'),
#  (',', ','),
#  ('breathe', 'NN'),
#  ('freedom', 'NN'),
#  (',', ','),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('also', 'RB'),
#  ('breathe', 'VBP'),
#  ('love', 'NN'),
#  (',', ','),
#  ('compassion', 'NN'),
#  (',', ','),
#  ('understanding', 'VBG'),
#  ('towards', 'NNS'),
#  ('one', 'CD'),
#  ('another', 'DT'),
#  ('.', '.'),
#  ('children', 'NNS'),
#  ('future', 'JJ'),
#  ('nation', 'NN'),
#  (',', ','),
#  ('responsibility', 'NN'),
#  ('ensure', 'VB'),
#  ('grow', 'JJ'),
#  ('environment', 'NN'),
#  ('freedom', 'NN'),
#  ('cherished', 'VBD'),
#  ('protected', 'VBN'),
#  ('.', '.'),
#  ('Let', 'VB'),
#  ('us', 'PRP'),
#  ('teach', 'VB'),
#  ('value', 'NN'),
#  ('freedom', 'NN'),
#  ('importance', 'NN'),
#  ('using', 'VBG'),
#  ('greater', 'JJR'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('conclusion', 'NN'),
#  (',', ','),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('celebrate', 'VB'),
#  ('freedom', 'NN'),
#  ('gratitude', 'NN'),
#  ('pride', 'NN'),
#  ('.', '.'),
#  ('May', 'NNP'),
#  ('always', 'RB'),
#  ('remember', 'VB'),
#  ('freedom', 'NN'),
#  ('precious', 'JJ'),
#  ('gift', 'NN'),
#  ('must', 'MD'),
#  ('cherish', 'VB'),
#  ('protect', 'JJ'),
#  ('future', 'JJ'),
#  ('generations', 'NNS'),
#  ('.', '.'),
#  ('nation', 'NN'),
#  ('collective', 'JJ'),
#  ('home', 'NN'),
#  (',', ','),
#  ('freedom', 'NN'),
#  ('foundation', 'NN'),
#  ('upon', 'IN'),
#  ('build', 'JJ'),
#  ('dreams', 'NNS'),
#  ('.', '.'),
#  ('Let', 'VB'),
#  ('us', 'PRP'),
#  ('work', 'VB'),
#  ('together', 'RB'),
#  ('create', 'JJ'),
#  ('future', 'NN'),
#  ('freedom', 'NN'),
#  ('flourishes', 'NNS'),
#  ('every', 'DT'),
#  ('citizen', 'NN'),
#  ('live', 'JJ'),
#  ('dignity', 'NN'),
#  ('respect', 'NN'),
#  ('.', '.'),
#  ('india', 'JJ'),
#  ('land', 'NN'),
#  ('diversity', 'NN'),
#  (',', ','),
#  ('freedom', 'NN'),
#  ('testament', 'NN'),
#  ('strength', 'NN'),
#  ('comes', 'VBZ'),
#  ('embracing', 'VBG'),
#  ('differences', 'NNS'),
#  ('.', '.'),
#  ('Let', 'VB'),
#  ('us', 'PRP'),
#  ('celebrate', 'VB'),
#  ('diversity', 'NN'),
#  ('work', 'NN'),
#  ('towards', 'RB'),
#  ('harmonious', 'JJ'),
#  ('society', 'NN'),
#  ('everyone', 'NN'),
#  ('enjoy', 'NN'),
#  ('freedoms', 'NNS'),
#  ('without', 'IN'),
#  ('fear', 'NN'),
#  ('discrimination', 'NN'),
#  ('.', '.'),
#  ('Thank', 'NNP'),
#  (',', ','),
#  ('Jai', 'NNP'),
#  ('Hind', 'NNP'),
#  ('!', '.')]

# %%
sentence='The Taj Mahal is a beautiful place'.split()

sentence
# Out:
# ['The', 'Taj', 'Mahal', 'is', 'a', 'beautiful', 'place']

# %%
# pos_tag_sents function expects a list of sentences as input but sentences is list of words so changing into a list below

nltk.pos_tag_sents([sentence])
# Out:
# [[('The', 'DT'),
#   ('Taj', 'NNP'),
#   ('Mahal', 'NNP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('beautiful', 'JJ'),
#   ('place', 'NN')]]

# %%
#this needs a list of words as input
nltk.pos_tag(sentence)
# Out:
# [('The', 'DT'),
#  ('Taj', 'NNP'),
#  ('Mahal', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('place', 'NN')]
